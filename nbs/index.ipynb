# %%
#| hide
from Hack3.core import *

# %% [markdown]
# # Hack3
#
# >

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install Hack3 in Development mode

# %% [markdown]
# ```sh
# # make sure Hack3 package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to Hack3
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/isc-ryoung/Hack3.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c isc-ryoung Hack3
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install Hack3
# ```
#
#
# [repo]: https://github.com/isc-ryoung/Hack3
# [docs]: https://isc-ryoung.github.io/Hack3/
# [pypi]: https://pypi.org/project/Hack3/
# [conda]: https://anaconda.org/isc-ryoung/Hack3

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/isc-ryoung/Hack3
# [docs]: https://isc-ryoung.github.io/Hack3/
# [pypi]: https://pypi.org/project/Hack3/
# [conda]: https://anaconda.org/isc-ryoung/Hack3

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
